# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport

import matplotlib 
from matplotlib import pyplot as plt
from matplotlib import style
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
# Out:
# C:\Users\A803377\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20560/2966616683.py in <module>
#       2 import pandas as pd
#       3 import seaborn as sns
# ----> 4 from pandas_profiling import ProfileReport
#       5
#       6 import matplotlib
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# ...

# %%
# !pip install cloud-sql-python-connector[pytds]

# %%
from google.cloud.sql.connector import Connector
import sqlalchemy
import pytds

# initialize Connector object
connector = Connector()


conn = connector.connect
("10.27.10.7", 
"pytds",
user="svc_tableau_dev",
password="Onestream!@#",
db="TableauDB")

# fts.fast_to_sql(df,'rpt.ManualClearonInventory_Weekly',conn, if_exists="append", custom={'G/L acct':'nvarchar(225)','Plant':'nvarchar(225)','CoCd':'nvarchar(225)','Material':'nvarchar(225)','Month':'nvarchar(225)',
#                                                                                   'Year':'nvarchar(225)','Day':'nvarchar(225)','Material':'nvarchar(225)','Material Description':'nvarchar(225)','Unit':'nvarchar(225)',
#                                                                                          'Currency':'nvarchar(225)','Type':'nvarchar(225)','Total Value':'float','Total Stock':'float'}, temp=False)


connector.close()
# Out:
#   File "C:\Users\A803377\AppData\Local\Temp/ipykernel_4648/3277673216.py", line 12
#     user="svc_tableau_dev",
#         ^
# SyntaxError: invalid syntax

# %%
# import pandas as pd
# import glob

# # getting excel files from Directory Desktop
# path = r'C:\Users\A803377\OneDrive - Solenis LLC\Documents\Clearon Inventory Historical'

# # read all the files with extension .xlsx i.e. excel 
# filenames = glob.glob(path + "\*.xlsx")
# print('File names:', filenames)

# dfs = {}

# # for loop to iterate all excel files 
# # loop over the list of csv files
# for f in filenames:
    
#     # read the csv file
#     dfs[f.split("\\")[-1]] = pd.read_excel(f,sheet_name=2)
      
#     # print the location and filename
#     print('Location:', f)
#     print('File Name:', f.split("\\")[-1],'\n')

# %%
# # Reading Path of Latest Excel file 
# import glob
# import os.path

# folder_path = r'C:\Users\A803377\Clearon Inventory Historical'
# file_type = r'\*xlsx'
# files = glob.glob(folder_path + file_type)
# max_file = max(files, key=os.path.getctime)

# print(max_file)

# %%
# # df=pd.read_excel(r'C:\Users\A803377\Downloads\Inventory - 02.28.22.xlsx',sheet_name=2)

# # df=dfs[list(dfs)[10]].copy()
# df=pd.read_excel(max_file,sheet_name=2)


# df["Month"] = df["Month"].apply(lambda x: '{0:0>2}'.format(x))
# df["Plant"] = df["Plant"].apply(lambda x: '{0:0>4}'.format(x))
# df["Day"] = '30'
# df["CoCd"] = 'US33'

# # df['Reporting_Date'] = ((pd.Timestamp.today()- timedelta(days=8)).strftime('%Y-%m-%d')) 
# # df['Reporting_Date'] =  pd.to_datetime(df['Reporting_Date'], format='%Y-%m-%d')

# df[['G/L acct','Plant','CoCd', 'Month','Year','Day','Material', 'Material Description', 'Unit','Crcy','Type']] = df[['G/L acct','Plant','CoCd', 'Month','Year','Day','Material', 'Material Description', 'Unit','Crcy','Type']].astype('string')
# # Changing Naming Convention 
# df.rename(columns = {'    Total Value':'Total Value','Crcy':'Currency','   Total Stock':'Total Stock'}, inplace = True)

# df = df.replace(np.nan, '', regex=True)

# # df[['Total Stock','Total Value']] = df[['Total Stock','Total Value']].replace('', 0.0, regex=True)
# # df[['Total Stock','Total Value']] = df[['Total Stock','Total Value']].replace('-', 0.0, regex=True)
# # df[['Total Stock','Total Value']] = df[['Total Stock','Total Value']].astype('float64')
# df

# %%
# df.info()

# %%
# import pandas as pd
# import warnings
# warnings.filterwarnings("ignore")
# import urllib
# import sqlalchemy as sa
# import pyodbc
# import time
# from fast_to_sql import fast_to_sql as fts

# start = time.time()
# #Connecting to SQL 
# conn = pyodbc.connect("""
# DRIVER={SQL Server Native Client 11.0};
# SERVER= NAAZUREEDWS01;
# UID= svc_tableau_dev;
# PWD= EwSol@321$;
# DATABASE=TableauDB;
# trusted_connection=Yes""")

# fts.fast_to_sql(df,'rpt.ManualClearonInventory',conn, if_exists="append", custom={'G/L acct':'nvarchar(225)','Plant':'nvarchar(225)','Month':'nvarchar(225)','Year':'nvarchar(225)','Material':'nvarchar(225)','Material Description':'nvarchar(225)','Unit':'nvarchar(225)','Currency':'nvarchar(225)','Type':'nvarchar(225)'}, temp=False)

# conn.commit()
# conn.close()
# end = time.time()
# delta = end - start
# print("took %.2f seconds to process" % delta)
# print("Update Completed")

# %%
[4:15 PM] Hari Babu Gorantla
EDWDBData.[rpt].[Manual_DeepDivePlantSpend_Costcenters_SGA] Deep

# %% [markdown]
# # Inventory weekly

# %%
# import pandas as pd
# import glob

# # getting excel files from Directory Desktop
# path = r'C:\Users\A803377\Clearon Inventory_Weekly'

# # read all the files with extension .xlsx i.e. excel 
# filenames = glob.glob(path + "\*.xlsx")
# print('File names:', filenames)

# dfs = {}

# # for loop to iterate all excel files 
# # loop over the list of csv files
# for f in filenames:
    
#     # read the csv file
#     dfs[f.split("\\")[-1]] = pd.read_excel(f)
      
#     # print the location and filename
#     print('Location:', f)
#     print('File Name:', f.split("\\")[-1],'\n')

# %%
df= pd.read_excel(r'C:\Users\A803377\Downloads\SQL Tables_Columns.xlsx',sheet_name=2,keep_default_na=False)
# df_oneStream= pd.read_csv(r'C:\Users\A803377\Downloads\Reporting_CubeData_2023M9.csv', keep_default_na=False)
df
# Out:
#       TABLE_CATALOG TABLE_SCHEMA                   TABLE_NAME
# 0         TableauDB          dbo  ManualEHSActionDatabaseFY21  \
# 1         TableauDB          dbo  ManualEHSActionDatabaseFY21
# 2         TableauDB          dbo  ManualEHSActionDatabaseFY21
# 3         TableauDB          dbo  ManualEHSActionDatabaseFY21
# 4         TableauDB          dbo  ManualEHSActionDatabaseFY21
# ...             ...          ...                          ...
# 21763     TableauDB         test               testOpen Order
# 21764     TableauDB         test               testOpen Order
# 21765     TableauDB         test               testOpen Order
# 21766     TableauDB         test               testOpen Order
# 21767     TableauDB         test               testOpen Order
#
#                         COLUMN_NAME  ORDINAL_POSITION DATA_TYPE
# 0                     Action Number                 1  nvarchar
# 1                     Business Unit                 2  nvarchar
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21768 entries, 0 to 21767
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TABLE_CATALOG     21768 non-null  object
#  1   TABLE_SCHEMA      21768 non-null  object
#  2   TABLE_NAME        21768 non-null  object
#  3   COLUMN_NAME       21764 non-null  object
#  4   ORDINAL_POSITION  21768 non-null  int64
#  5   DATA_TYPE         21768 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1020.5+ KB

# %%
df["TABLE_NAME"]= df["TABLE_NAME"].replace({'-':'_', '__':'_',' ':'_','$':'',
                                                                    '%':'per','#':'_no_',
                                                                   '+':'plus','<':'','>':'','$':'','@':'','!':'','=':''},regex=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20560/2386911936.py in <module>
# ----> 1 df["TABLE_NAME"]= df["TABLE_NAME"].replace({'-':'_', '__':'_',' ':'_','$':'',
#       2                                                                     '%':'per','#':'_no_',
#       3                                                                    '+':'plus','<':'','>':'','$':'','@':'','!':'','=':''},regex=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5217         method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5218     ) -> Series | None:
# -> 5219         return super().replace(
#    5220             to_replace=to_replace,
#    5221             value=value,
#
# ...

# %%
df["TABLE_NAME"]= df["TABLE_NAME"].replace({'%':'per','#':'_no_', '+':'plus'},regex=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20560/1626275270.py in <module>
# ----> 1 df["TABLE_NAME"]= df["TABLE_NAME"].replace({'%':'per','#':'_no_', '+':'plus'},regex=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5217         method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5218     ) -> Series | None:
# -> 5219         return super().replace(
#    5220             to_replace=to_replace,
#    5221             value=value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    7297                 to_replace, value = keys, values
#    7298
# -> 7299             return self.replace(
# ...

# %%
# Reading Path of Latest Excel file 
import glob
import os.path

folder_path = r'C:\Users\A803377\Clearon Inventory_Weekly'
file_type = r'\*xlsx'
files = glob.glob(folder_path + file_type)
max_file = max(files, key=os.path.getctime)

print(max_file)
# Out:
# C:\Users\A803377\Clearon Inventory_Weekly\Inventory Subledger 3_13_2023.xlsx

# %%
from datetime import timedelta

df=pd.read_excel(max_file)
# df=pd.read_excel(max_file,sheet_name=2)

# df=dfs[list(dfs)[0]].copy()
df[["CoCd",'ValA']] = df[["CoCd",'ValA']].astype(float).astype('string').replace('\.0', '', regex=True)
# df[['CoCd','Plant']] = df[['CoCd','Plant']].astype(float).astype('string').replace('\.0', '', regex=True)

df["CoCd"] = df["CoCd"].apply(lambda x: '{0:0>4}'.format(x))
df["ValA"] = df["ValA"].apply(lambda x: '{0:0>4}'.format(x))

df["Month"] = df["Month"].apply(lambda x: '{0:0>2}'.format(x))
df["Day"] = df["Day"].apply(lambda x: '{0:0>2}'.format(x))
df['CoCd'] = 'US33'
# df[["CoCd"]] = df[["CoCd"]].astype('string')
df[['G/L acct','ValA','CoCd', 'Month','Year','Day','Material', 'Material Description', 'Unit','Crcy','Type']] = df[['G/L acct','ValA','CoCd', 'Month','Year','Day','Material', 'Material Description', 'Unit','Crcy','Type']].astype('string')

df.rename(columns = {'   Total Stock':'Total Stock','Crcy':'Currency','    Total Value':'Total Value','ValA':'Plant'}, inplace = True)

# # df['Reporting_Date'] = (pd.Timestamp.today().strftime('%Y-%m-%d')) 

df['Reporting_Date'] = ((pd.Timestamp.today()- timedelta(days=1)).strftime('%Y-%m-%d')) 
df['Reporting_Date'] =  pd.to_datetime(df['Reporting_Date'], format='%Y-%m-%d')

df = df.replace(np.nan, '', regex=True)

df[['Total Stock','Total Value']] = df[['Total Stock','Total Value']].replace('', 0.0, regex=True)
df[['Total Stock','Total Value']] = df[['Total Stock','Total Value']].replace('-', 0.0, regex=True)
df[['Total Stock','Total Value']] = df[['Total Stock','Total Value']].astype('float64')

df
# Out:
#      G/L acct Plant  CoCd Day Month  Year  Material  \
# 0      131000  2700  US33  13    03  2023  32000120
# 1      131000  2700  US33  13    03  2023  32000121
# 2      131000  2700  US33  13    03  2023  32000122
# 3      131000  2700  US33  13    03  2023  32000123
# 4      131000  2700  US33  13    03  2023  32000124
# ...       ...   ...   ...  ..   ...   ...       ...
# 8515   134510  2700  US33  13    03  2023    CL9890
# 8516   134510  2700  US33  13    03  2023     CL990
# 8517   134510  2700  US33  13    03  2023    CL9900
# 8518   134510  2700  US33  13    03  2023    CL9910
# 8519   134510  2700  US33  13    03  2023    CL9930
#
#                Material Description  Total Stock Unit    Total Value Currency  \
# 0                              UREA      20572.0   LB    7137.060000      USD
# 1                  CHLORINE, LIQUID    1346010.0   LB  756195.130000      USD
# 2                  CAUSTIC SODA 50%     779993.0   LB  406076.650000      USD
# ...

# %%
# df.columns

# %%
# print((pd.Timestamp.today()- timedelta(days=22)).strftime('%Y-%m-%d'))

# %%
# df.info()

# DRIVER={SQL Server Native Client 11.0};
# SERVER= NAAZUREEDWS01;
# UID= svc_tableau_dev;
# PWD= EwSol@321$;
# DATABASE=TableauDB;
# trusted_connection=Yes""")

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import urllib
import sqlalchemy as sa
import pyodbc
import time
from fast_to_sql import fast_to_sql as fts

start = time.time()
#Connecting to SQL 
conn = pyodbc.connect("""
DRIVER={SQL Server Native Client 11.0};
SERVER= 10.27.10.7;
UID= svc_tableau_dev;
PWD= Onestream!@#;
DATABASE=TableauDB;
trusted_connection=Yes""")

fts.fast_to_sql(df,'rpt.ManualClearonInventory_Weekly_test',conn, if_exists="append", custom={'G/L acct':'nvarchar(225)','Plant':'nvarchar(225)','CoCd':'nvarchar(225)','Material':'nvarchar(225)','Month':'nvarchar(225)',
                                                                                  'Year':'nvarchar(225)','Day':'nvarchar(225)','Material':'nvarchar(225)','Material Description':'nvarchar(225)','Unit':'nvarchar(225)',
                                                                                         'Currency':'nvarchar(225)','Type':'nvarchar(225)','Total Value':'float','Total Stock':'float'}, temp=False)

conn.commit()
conn.close()
end = time.time()
delta = end - start
print("took %.2f seconds to process" % delta)
print("Update Completed")
print(df['[Reporting_Date]'].unique())
print('Last File Uploaded :',max_file)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4648/1930429820.py in <module>
#      10 start = time.time()
#      11 #Connecting to SQL
# ---> 12 conn = pyodbc.connect("""
#      13 DRIVER={SQL Server Native Client 11.0};
#      14 SERVER= 10.27.10.7;
#
# OperationalError: ('08001', '[08001] [Microsoft][SQL Server Native Client 11.0]Named Pipes Provider: Could not open a connection to SQL Server [53].  (53) (SQLDriverConnect); [08001] [Microsoft][SQL Server Native Client 11.0]Login timeout expired (0); [08001] [Microsoft][SQL Server Native Client 11.0]A network-related or instance-specific error has occurred while establishing a connection to SQL Server. Server is not found or not accessible. Check if instance name is correct and if SQL Server is configured to allow remote connections. For more information see SQL Server Books Online. (53)')

# %% [markdown]
# # Spent Report Historical

# %%
# import pandas as pd
# import glob

# # getting excel files from Directory Desktop
# path = r'C:\Users\A803377\Clearon Spend Weekly'

# # read all the files with extension .xlsx i.e. excel 
# filenames = glob.glob(path + "\*.xlsx")
# print('File names:', filenames)

# dfs = {}

# # for loop to iterate all excel files 
# # loop over the list of csv files
# for f in filenames:
    
#     # read the csv file
#     dfs[f.split("\\")[-1]] = pd.read_excel(f)  
      
#     # print the location and filename
#     print('Location:', f)
#     print('File Name:', f.split("\\")[-1],'\n')

# %%
# Reading Path of Latest Excel file 
import glob
import os.path

folder_path = r'C:\Users\A803377\Clearon Spend Weekly'
file_type = r'\*xlsx'
files = glob.glob(folder_path + file_type)
max_file = max(files, key=os.path.getctime)

print(max_file)
# Out:
# C:\Users\A803377\Clearon Spend Weekly\Spend Report 3_13_2023.xlsx

# %%
from datetime import timedelta

df=pd.read_excel(max_file)
# df=pd.read_excel(r'C:\Users\A803377\Clearon Spend Weekly\Spend Report 1_30_2023.xlsx',sheet_name=1)

# df=dfs[list(dfs)[8]].copy().fillna('')
# df[["CoCd"]] = df[["CoCd"]].astype(float).astype('string').replace('\.0', '', regex=True)
df[['Purchase Order', 'Vendor','Vendor Name','PO Item', 'Ship to Country','Ship to City', 'Ship to State','Del. Indicator','Material', 'Description', 'Material Group', 'Unit', 'Normalized Unit','Item Category', 'Acct Ass. Cat.', 'Incoterms', 'Invoice Payment Term','PO Payment Terms', 'Payment Term Name','Document Date(M/Y)', 'Invoice Receipt(M/Y)','Goods Received(M/Y)','Invoice Receipt Year','Goods Received Year','Vendor Mat. No','Invoice Reference']] = df[['Purchase Order', 'Vendor','Vendor Name','PO Item', 'Ship to Country','Ship to City', 'Ship to State','Del. Indicator','Material','Description', 'Material Group', 'Unit', 'Normalized Unit','Item Category', 'Acct Ass. Cat.', 'Incoterms', 'Invoice Payment Term','PO Payment Terms', 'Payment Term Name','Document Date(M/Y)', 'Invoice Receipt(M/Y)','Goods Received(M/Y)','Invoice Receipt Year','Goods Received Year','Vendor Mat. No','Invoice Reference']].astype('string').replace('\.0', '', regex=True)
df["Net Price"] = df["Net Price"].replace('', 0.0, regex=True)
df["Description"] = df["Description"].str.strip()
# df = df.replace(np.nan, '', regex=True)
df["Net Price"] = df["Net Price"].astype("float64")

df['Document Date'] = pd.to_datetime(df['Document Date'], format='%Y-%m-%d')
# df['Document Date'] = pd.to_datetime(df['Document Date']).dt.strftime('%Y-%m-%d')
# df['Reporting_Date'] = ((pd.Timestamp.today()- timedelta(days=1)).strftime('%Y-%m-%d')) 
df = df.replace(r"^ +| +$", r"", regex=True)
df = df.replace(np.nan, '', regex=True)
df.drop(df.tail(1).index,inplace=True) # drop last n rows

df.drop(["Invoice Reference"],axis= 1,inplace=True)

df
# Out:
#      Purchase Order   Vendor                    Vendor Name Ship to Country  \
# 0        4500246477  1012267  STATE ELECTRIC SUPPLY COMPANY              US
# 1        4500246478  1013826                        M-I LLC              US
# 2        4500246479  1014413      Tabor Machine Company LLC              US
# 3        4500246480  1018921                STATIONERS INC.              US
# 4        4500246481  1000956                     MRC GLOBAL              US
# ...             ...      ...                            ...             ...
# 4092     6000000213  1012117             NOVA RUBBER CO INC              US
# 4093     6000000213  1012117             NOVA RUBBER CO INC              US
# 4094     6000000213  1012117             NOVA RUBBER CO INC              US
# 4095     6000000213  1012117             NOVA RUBBER CO INC              US
# 4096     6000000213  1012117             NOVA RUBBER CO INC              US
#
# ...

# %%
# df.drop(["Description","Vendor Name","Payment Term Name"],axis= 1,inplace=True)
# df.drop(["Invoice Reference"],axis= 1,inplace=True)

# df["Description"].lenmax()
# df.astype(str).apply(lambda s: s.str.len()).max()

# print (df.Description.map(lambda x: len(x)).min())

# %%
# df['Net Value'].sum()

# %%
# df.info()

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import urllib
import sqlalchemy as sa
import pyodbc
import time
from fast_to_sql import fast_to_sql as fts

start = time.time()
#Connecting to SQL 
conn = pyodbc.connect("""
DRIVER={SQL Server Native Client 11.0};
SERVER= NAAZUREEDWS01;
UID= svc_tableau_dev;
PWD= EwSol@321$;
DATABASE=PricingHUBDB;
trusted_connection=Yes""")
                      

# fts.fast_to_sql( df,'rpt.ManualClearonSpendReport',conn, if_exists="append",custom={'Purchase Order':'nvarchar(225)','Vendor':'nvarchar(225)','Ship to Country':'nvarchar(225)','Ship to City':'nvarchar(225)','Ship to State':'nvarchar(225)','Del. Indicator':'nvarchar(225)','PO Item':'nvarchar(225)','Material':'nvarchar(225)','Material Group':'nvarchar(225)',
#                                                                             'Unit':'nvarchar(225)','Normalized Unit':'nvarchar(225)','Item Category':'nvarchar(225)','Acct Ass. Cat.':'nvarchar(225)','Incoterms':'nvarchar(225)','Invoice Payment Term':'nvarchar(225)','PO Payment Terms':'nvarchar(225)','Document Date(M/Y)':'nvarchar(225)','Invoice Receipt Year':'nvarchar(225)',
#                                                                               'Invoice Receipt(M/Y)':'nvarchar(225)','Goods Received Year':'nvarchar(225)','Goods Received(M/Y)':'nvarchar(225)','Vendor Mat. No':'nvarchar(225)',"Document Date":'datetime2(7)','Order Qty':'float', 'Normalized Order Qty':'float', 'Net Price':'float', 'Net Value':'float',
#                                                                                 'Freight Unit Price':'float', 'Received Qty':'float', 'Norm Received Qty':'float','Received Amount':'float', 'Invoice Amount':'float', 'Norm Inv Unit Price':'float'}, temp=False)
                                                                      
fts.fast_to_sql( df,'rpt.ManualClearonSpendReport_Weekly',conn, if_exists="replace",custom={'Purchase Order':'nvarchar(225)','Vendor':'nvarchar(225)','Ship to Country':'nvarchar(225)','Ship to City':'nvarchar(225)','Ship to State':'nvarchar(225)','Del. Indicator':'nvarchar(225)','PO Item':'nvarchar(225)','Material':'nvarchar(225)','Material Group':'nvarchar(225)',
                                                                            'Unit':'nvarchar(225)','Normalized Unit':'nvarchar(225)','Item Category':'nvarchar(225)','Acct Ass. Cat.':'nvarchar(225)','Incoterms':'nvarchar(225)','Invoice Payment Term':'nvarchar(225)','PO Payment Terms':'nvarchar(225)','Document Date(M/Y)':'nvarchar(225)','Invoice Receipt Year':'nvarchar(225)',
                                                                              'Invoice Receipt(M/Y)':'nvarchar(225)','Goods Received Year':'nvarchar(225)','Goods Received(M/Y)':'nvarchar(225)','Vendor Mat. No':'nvarchar(225)',"Document Date":'datetime2(7)','Order Qty':'float', 'Normalized Order Qty':'float', 'Net Price':'float', 'Net Value':'float',
                                                                                'Freight Unit Price':'float', 'Received Qty':'float', 'Norm Received Qty':'float','Received Amount':'float', 'Invoice Amount':'float', 'Norm Inv Unit Price':'float'}, temp=False)
                                                                      


conn.commit()
conn.close()
end = time.time()
delta = end - start
print("took %.2f seconds to process" % delta)
print("Update Completed")
# print(df['Reporting_Date'].unique())
print('Last File Uploaded :',max_file)
# Out:
# took 8.44 seconds to process
# Update Completed
# Last File Uploaded : C:\Users\A803377\Clearon Spend Weekly\Spend Report 3_13_2023.xlsx

# %%
# import pandas as pd
# import sqlalchemy as sa
# import time

# start = time.time()

# connection_string = ("""
# DRIVER={SQL Server Native Client 11.0};
# SERVER= NAAZUREEDWS01;
# UID= svc_tableau_dev;
# PWD= EwSol@321$;
# DATABASE=TableauDB;
# trusted_connection=Yes""")

# connection_url = sa.engine.URL.create(
#     "mssql+pyodbc", 
#     query=dict(odbc_connect=connection_string)
# )
# engine = sa.create_engine(connection_url, fast_executemany=True)

# df.to_sql('ManualClearonSpendReport1',engine,schema= 'rpt',if_exists= "append", index=False)


# end = time.time()
# delta = end - start
# print("took %.2f seconds to process" % delta)
# print("Update Completed")

# %%
# df.columns

# %%
# conn.close()

# %%
# conn = pyodbc.connect("""
# DRIVER={SQL Server Native Client 11.0};
# SERVER= NAAZUREEDWS01;
# UID= svc_tableau_dev;
# PWD= EwSol@321$;
# DATABASE=TableauDB;
# trusted_connection=Yes""")

# %% [markdown]
# # Production Report Weekly

# %%
# Reading Path of Latest Excel file 
import glob
import os.path

folder_path = r'C:\Users\A803377\Clearon Production Report'
file_type = r'\*xlsx'
files = glob.glob(folder_path + file_type)
max_file = max(files, key=os.path.getctime)

print(max_file)
# Out:
# C:\Users\A803377\Clearon Production Report\Production Report 3_13_2023.xlsx

# %%
from datetime import timedelta

df=pd.read_excel(max_file)

# df= pd.read_excel(r'C:\Users\A803377\Downloads\Production Report 11_21_2022.xlsx',sheet_name=0)
df[['Product Element', 'O-grade','Comments']] = df[['Product Element', 'O-grade','Comments']].astype('string')

# df = df.replace(np.nan, '', regex=True)

df[["Actual","Planned"]] = df[["Actual","Planned"]].replace(' ', 0.0, regex=True)
df[["Actual","Planned"]] = df[["Actual","Planned"]].replace('-', 0.0, regex=True)

df[["Actual","Planned"]] = df[["Actual","Planned"]].astype("float64")
# df[["Actual","Planned"]] = df[["Actual","Planned"]].str.replace(' ', '').astype(float)
df["Actual"] = df["Actual"].replace(' ', 0.0, regex=True)

df['Reporting_Date'] = ((pd.Timestamp.today()- timedelta(days=1)).strftime('%Y-%m-%d')) 
df['Reporting_Date'] =  pd.to_datetime(df['Reporting_Date'], format='%Y-%m-%d')

df = df.replace(np.nan, '', regex=True)

df
# Out:
#    Product Element       Date   Actual   Planned O-grade  \
# 0           CDB-90 2023-03-01  83790.0   99225.0    6615
# 1           CDB-90 2023-03-02  11025.0  145530.0    -
# 2           CDB-90 2023-03-03      0.0  145530.0    -
# 3           CDB-90 2023-03-04      0.0  145530.0    -
# 4           CDB-90 2023-03-05      0.0  145530.0    -
# 5           CDB-90 2023-03-06      0.0  145530.0    -
# 6           CDB-90 2023-03-07      0.0   77175.0    -
# 7           CDB-90 2023-03-08      0.0   61740.0    -
# 8           CDB-90 2023-03-09      0.0  145530.0    -
# 9           CDB-90 2023-03-10      0.0  145530.0    -
# 10          CDB-90 2023-03-11      0.0  145530.0    -
# 11          CDB-90 2023-03-12      0.0  145530.0    -
# 12          CDB-90 2023-03-13      0.0  145530.0
# 13          CDB-90 2023-03-14      0.0  145530.0
# 14          CDB-90 2023-03-15      0.0   99225.0
# 15          CDB-90 2023-03-16      0.0  145530.0
# 16          CDB-90 2023-03-17      0.0  145530.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Element  93 non-null     string
#  1   Date             93 non-null     datetime64[ns]
#  2   Actual           93 non-null     float64
#  3   Planned          93 non-null     float64
#  4   O-grade          93 non-null     string
#  5   Comments         93 non-null     string
#  6   Reporting_Date   93 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), string(3)
# memory usage: 5.2 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Element  84 non-null     string
#  1   Date             84 non-null     datetime64[ns]
#  2   Actual           84 non-null     float64
#  3   Planned          84 non-null     float64
#  4   O-grade          84 non-null     string
#  5   Comments         84 non-null     string
#  6   Reporting_Date   84 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), string(3)
# memory usage: 4.7 KB

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import urllib
import sqlalchemy as sa
import pyodbc
import time
from fast_to_sql import fast_to_sql as fts

start = time.time()
#Connecting to SQL 
conn = pyodbc.connect("""
DRIVER={SQL Server Native Client 11.0};
SERVER= NAAZUREEDWS01;
UID= svc_tableau_dev;
PWD= EwSol@321$;
DATABASE=TableauDB;
trusted_connection=Yes""")

fts.fast_to_sql(df,'rpt.ManualClearonProductionReport_Weekly',conn, if_exists="append", custom={'Product Element':'nvarchar(225)','Actual':'float(53)',
                                                                                               'Planned':'float(53)','O-grade':'nvarchar(225)',
                                                                                               'Comments':'nvarchar(225)'}, temp=False)

conn.commit()
conn.close()
end = time.time()
delta = end - start
print("took %.2f seconds to process" % delta)
print("Update Completed")
print(df['[Reporting_Date]'].unique())
print('Last File Uploaded :',max_file)
# Out:
# took 4.08 seconds to process
# Update Completed
# ['2023-03-13T00:00:00.000000000']
# Last File Uploaded : C:\Users\A803377\Clearon Production Report\Production Report 3_13_2023.xlsx

# %%
cnx = mysql.connector.connect(database='world')
cursor = cnx.cursor(dictionary=True)
cursor.execute("SELECT * FROM country WHERE Continent = 'Europe'")

print("Countries in Europe:")
for row in cursor:
    print("* {Name}".format(Name=row['Name']))

# %%
import pyodbc 
cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                        "Server=NAAZUREEDWS01;"
                        "Database=TableauDB;"
                        "uid=svc_tableau_dev;pwd=EwSol@321$;"
                        "Trusted_Connection=yes;")


# cursor = cnxn.cursor()
# cursor.execute('select Max([Reporting_Date] ) from TableauDB.[rpt].[ManualClearonDailySales]')


df_1 = pd.read_sql_query('select Max([Reporting_Date] ) as [Reporting_Date] from TableauDB.[rpt].[ManualClearonDailySales]', cnxn)

print(df_1)
# for i in cursor:
#     print(i)
    
cnxn.close()
# Out:
#   Reporting_Date
# 0     2023-02-20

# %%
cnxn.close()

# %%
dict = df.columns.to_dict('dict')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29160/4050535349.py in <module>
# ----> 1 dict = df.columns.to_dict('dict')
#
# AttributeError: 'Index' object has no attribute 'to_dict'

# %%
my_dict = { df.columns[i]: 'nvarchar(225)' for i in range(len(df.columns))}

# %%
df.columns[0]
# Out:
# 'Product Element'

# %%
my_dict
# Out:
# {'Product Element': 'nvarchar(225)',
#  'Date': 'nvarchar(225)',
#  'Actual': 'nvarchar(225)',
#  'Planned': 'nvarchar(225)',
#  'O-grade': 'nvarchar(225)',
#  'Comments': 'nvarchar(225)',
#  'Reporting_Date': 'nvarchar(225)'}

# %%
my_dict =  {df.columns[i]: 'nvarchar(225)'  if df.dtypes[i].name == 'string' else df.columns[i]: 'float' for i in range(len(df.columns))}
# Out:
#   File "C:\Users\A803377\AppData\Local\Temp/ipykernel_29160/3318024522.py", line 1
#     my_dict =  {df.columns[i]: 'nvarchar(225)'  if df.dtypes[i].name == 'string' else df.columns[i]: 'float' for i in range(len(df.columns))}
#                                                                                                    ^
# SyntaxError: invalid syntax

# %%
range(len(df.columns)-2)
# Out:
# range(0, 5)

# %%
df.columns[0].dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29160/105059109.py in <module>
# ----> 1 df.columns[0].dtype
#
# AttributeError: 'str' object has no attribute 'dtype'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Element  90 non-null     string
#  1   Date             90 non-null     datetime64[ns]
#  2   Actual           90 non-null     float64
#  3   Planned          90 non-null     float64
#  4   O-grade          90 non-null     string
#  5   Comments         90 non-null     string
#  6   Reporting_Date   90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), string(3)
# memory usage: 5.0 KB

# %%
type('Product Element')
# Out:
# str

# %%
['Product Element'].dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29160/1883470587.py in <module>
# ----> 1 ['Product Element'].dtype()
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
df.columns[1].dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29160/2008734701.py in <module>
# ----> 1 [df.columns[1]].dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
df.dtypes[1].name
# Out:
# 'datetime64[ns]'
