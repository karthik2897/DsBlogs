# %%
import numpy as np 
import pandas as pd
import seaborn as sns
pd.options.display.float_format = '{:,.5f}'.format


import matplotlib 
from matplotlib import pyplot as plt
from matplotlib import style
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
# Out:
# C:\Users\A803377\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# df_oneStream= pd.read_excel(r'C:\Users\A803377\Downloads\M12 Tableau Extract.xlsx',sheet_name=1,keep_default_na=False)
df_oneStream= pd.read_excel(r'C:\Users\A803377\Downloads\Reporting_CubeData_TableauTieTo_M5 - Copy.xlsx',sheet_name=1,keep_default_na=False)


# df_oneStream= pd.read_csv(r'C:\Users\A803377\Downloads\Reporting_CubeData_TableauTieTo_M4.csv', keep_default_na=False)
df_oneStream
# Out:
#             Cube  Entity Currency    Rate  Parent  Cons  Scenario    Time
# 0      Reporting    1020      USD 1.00000           USD    Actual  2024M1  \
# 1      Reporting    1020      USD 1.00000           USD    Actual  2024M1
# 2      Reporting    1020      USD 1.00000           USD    Actual  2024M1
# 3      Reporting    1020      USD 1.00000           USD    Actual  2024M1
# 4      Reporting    1020      USD 1.00000           USD    Actual  2024M1
# ...          ...     ...      ...     ...     ...   ...       ...     ...
# 45603  Reporting     242      EUR 1.06820           EUR    Actual  2024M3
# 45604  Reporting     242      EUR 1.06820           EUR    Actual  2024M4
# 45605  Reporting     242      EUR 1.06820           EUR    Actual  2024M5
# 45606  Reporting    1995      USD 1.00000           USD    Actual  2024M3
# 45607  Reporting    1998      USD 1.00000           USD    Actual  2024M3
#
#            View       Account  Flow  Origin   IC           UD1   UD2  UD3
# ...

# %%
df_oneStream = df_oneStream[[' Entity',' Account',' UD1','CC Rate Amount',' Time']]
df_oneStream.rename(columns = {' Entity':'Company Code',' UD1': 'Reporting_Line',' Account':'Account','CC Rate Amount':'Amount',' Time':'Fiscal Period'}, inplace = True)
df_oneStream= df_oneStream.groupby(["Company Code","Account","Reporting_Line",'Fiscal Period'],as_index=False)["Amount"].sum()
df_oneStream = df_oneStream.pivot_table(index=["Company Code","Reporting_Line",'Fiscal Period'],columns='Account',values='Amount',aggfunc='sum',).fillna(0)
df_oneStream.rename(columns = {'MGMT_GR_Prof':'GP'}, inplace = True)
df_oneStream.reset_index(inplace=True)

# Changes
df_oneStream['Company Code'] = df_oneStream['Company Code'].apply(lambda x: '{0:0>4}'.format(x))
df_oneStream["Reporting_Line"]= df_oneStream["Reporting_Line"].replace({'EMEA_IWT':'EU_IS', 'SD_IWALD':'RSA','SD_RSAE1':'RSA','SD_IWEUD':'RSA',
                                                                   'SD_RSAA1':'RSA','SD_RSAN1':'RSA','SD_IWAPD':'RSA','PS_NAM':'PS_NA','PS_SA':'PS_ZA'},regex=True)

df_oneStream["Reporting_Line"]= df_oneStream["Reporting_Line"].replace('None', 'NVOther',regex=True)
df_oneStream["Reporting_Line"]= df_oneStream["Reporting_Line"].replace('No_SG', 'NVOther',regex=True)
df_oneStream = df_oneStream.groupby(['Company Code','Reporting_Line','Fiscal Period'],as_index=False).sum()

df_oneStream
# Out:
# Account Company Code Reporting_Line Fiscal Period              GP
# 0               0011          EM_IN        2024M1 3,210,019.99186  \
# 1               0011          EM_IN        2024M2 2,712,697.80172
# 2               0011          EM_IN        2024M3 2,720,526.52704
# 3               0011          EM_IN        2024M4 2,874,401.22264
# 4               0011          EM_IN        2024M5 3,157,619.17920
# ...              ...            ...           ...             ...
# 2869            ZA01          PS_ZA        2024M1 2,881,438.89649
# 2870            ZA01          PS_ZA        2024M2 2,248,918.72133
# 2871            ZA01          PS_ZA        2024M3 1,999,336.22911
# 2872            ZA01          PS_ZA        2024M4 2,222,356.91216
# 2873            ZA01          PS_ZA        2024M5 2,007,060.56662
#
# Account         Revenue
# 0       7,661,202.53657
# 1       6,366,949.70635
# 2       6,429,166.96113
# 3       6,512,271.59395
# 4       7,180,069.41481
# ...

# %%
df_oneStream["Fiscal Period"]= df_oneStream["Fiscal Period"].replace({'2024M1': '2024001','2024M2': '2024002','2024M3': '2024003','2024M4': '2024004','2024M5': '2024005'},regex=True)
df_oneStream["Fiscal Period"] = df_oneStream["Fiscal Period"].astype('string')

# %%
# Diversey CC list 

a = ['0011','0110','0112','0113','0117','0118','0125','0126'
,'0127','0128','0130','0131','0133','0135','0139','0142'
,'0146','0150','0156','0157','0158','0159','0160','0161'
,'0180','0181','0182','0183','0185','0186','0191','0193'
,'0194','0195','0196','0198','0199','0200','0205','0207'
,'0211','0223','0224','0237','0242','0248','0249','0255'
,'0281','0291','0295','0305','0306','0307','0308','0309'
,'0429','0453','0454','0457','0458','0459','0461','0472'
,'0765','0812','0815','0817','0888','0968','0NL5','2071'
,'2333','2340','2350','2360','2380','2390','2400','2410'
,'2721','2983','3166','4000','4001','4002','4009','4010'
,'4020','4107','4185','4200','4209','4309','4400','4450'
,'4501','4509','4510','4550','4620','4630','4699','4730'
,'4809','4810','4900','4909','4959','4969','4990','5200'
,'5300','5410','5420','5430','5440','5460','5461','9474'
,'9475','9476','9478','9479','9480','9482','9483','9484'
,'C310','C460']
df_oneStream = df_oneStream[~df_oneStream['Company Code'].isin(a)]

# %%
df_oneStream = df_oneStream[df_oneStream["Reporting_Line"] == 'EM_IS']

# %%
df_Onestream_Rev = df_oneStream.groupby("Fiscal Period")["Revenue"].sum()
df_Onestream_Rev
# Out:
# Fiscal Period
# 2024001   13,593,382.92018
# 2024002   11,909,171.47953
# 2024003   13,486,576.48581
# 2024004   12,345,156.29764
# 2024005   11,853,379.20142
# Name: Revenue, dtype: float64

# %%
df_Onestream_GP = df_oneStream.groupby("Fiscal Period")["GP"].sum()
df_Onestream_GP
# Out:
# Fiscal Period
# 2024001   3,946,001.48600
# 2024002   3,738,425.47253
# 2024003   4,203,731.77538
# 2024004   4,203,493.24760
# 2024005   4,169,316.96549
# Name: GP, dtype: float64

# %%
df_CC_Currency= pd.read_excel(r'C:\Users\A803377\Downloads\Reporting_CubeData_TableauTieTo_M5 - Copy.xlsx',sheet_name=2,keep_default_na=False)

df_oneStream['Company Code'] = df_oneStream['Company Code'].apply(lambda x: '{0:0>4}'.format(x))
df_CC_Currency.rename(columns = {'Company':' Entity',' UD1': 'Reporting_Line',' Account':'Account',' Amount':'Amount',' Time':'Fiscal Period'}, inplace = True)

# df_oneStream= pd.read_csv(r'C:\Users\A803377\Downloads\Reporting_CubeData_TableauTieTo_M4.csv', keep_default_na=False)
df_CC_Currency
# Out:
#     Company Currency
# 0        11      TRY
# 1        70      RUB
# 2        71      RUB
# 3        72      RUB
# 4        73      EUR
# ..      ...      ...
# 578    Y008      MXN
# 579    Y009      USD
# 580    Y010      USD
# 581    ZA01      ZAR
# 582    ZA04      ZAR
#
# [583 rows x 2 columns]

# %%
df_Currency_Rate= pd.read_excel(r'C:\Users\A803377\Downloads\Reporting_CubeData_TableauTieTo_M5 - Copy.xlsx',sheet_name=3,keep_default_na=False)


# df_oneStream= pd.read_csv(r'C:\Users\A803377\Downloads\Reporting_CubeData_TableauTieTo_M4.csv', keep_default_na=False)
df_Currency_Rate
# Out:
#    BP FX Rate FromCurrency
# 0     0.27226          AED
# 1     0.00213          ARS
# 2     0.64263          AUD
# 3        NULL          BBD
# 4        NULL          BDT
# 5     0.54620          BGN
# 6     2.65259          BHD
# 7     0.20262          BRL
# 8     0.73931          CAD
# 9        NULL         CAD4
# 10    1.11307          CHF
# 11    0.00113          CLP
# 12    0.13708          CNY
# 13       NULL         CNY4
# 14    0.00025          COP
# 15    0.00187          CRC
# 16    0.04382          CZK
# 17    0.14326          DKK
# 18       NULL         DKK4
# 19    0.01762          DOP
# 20    0.00004          ECS
# 21    0.06827          EEK
# 22    0.03235          EGP
# 23    1.06820          EUR
# 24       NULL         EUR4
# 25    0.43946          FJD
# 26    1.23979          GBP
# 27       NULL         GBP4
# 28    0.08718          GHS
# 29    0.12710          GTQ
# 30    0.12774          HKD
# 31    0.14177          HRK
# 32    0.00276          HUF
# ...

# %%
import win32com.client
import os
from datetime import datetime, timedelta
import pytz  # Import pytz for timezone handling

# Connect to Outlook
outlook = win32com.client.Dispatch("Outlook.Application")
namespace = outlook.GetNamespace("MAPI")

# Access the shared mailbox
email_id = 'automationpx-team@solenis.com'  # Replace with the actual email ID
shared_mailbox = namespace.Folders[email_id]

# Access the Inbox of the shared mailbox
inbox = shared_mailbox.Folders['Inbox']  # Access Inbox

# Directory to save attachments
attachments_dir = r'C:\Users\A803377\Emails'  # Replace with your local path
os.makedirs(attachments_dir, exist_ok=True)

# Specify the date range (e.g., last 10 days)
days_to_check = 36  # Change to 20 for the last 20 days
start_date = datetime.now(pytz.utc) - timedelta(days=days_to_check)  # Make start_date timezone-aware

# Specify the sender's email address to filter by
sender_email = 'I.T@zhgplc.com'  # Replace with the actual sender's email


# Collect emails
emails = inbox.Items
emails.Sort("[ReceivedTime]", True)  # Sort emails by received time (most recent first)

# Loop through emails and process those within the specified date range and sender
for item in emails:
    # Check if the email is from the specified sender
    if item.SenderEmailAddress.lower() != sender_email.lower():
        continue  # Skip emails not from the specified sender

    # Get the received time in UTC
    received_time = item.ReceivedTime  # This should already be in the correct format

    # Check if the email is from the specified sender and within the date range
    if received_time < start_date or item.SenderEmailAddress.lower() != sender_email.lower():
        continue  # Skip emails outside the date range or not from the specified sender

    try:
        print(f"Processing email: {item.Subject}")

        if item.Attachments.Count > 0:
            # Use the received date of the email for the report date
            report_date = received_time.strftime("%Y-%m-%d")

            for attachment in item.Attachments:
                attachment_name = attachment.FileName
                attachment_path = os.path.join(attachments_dir, attachment_name)

                # Logic for renaming files based on email subject
                if "Order Line" in item.Subject:
                    new_file_name = f"{report_date} - Daily Orders - Zenith - Order Lines.csv"
                    attachment_path = os.path.join(attachments_dir, new_file_name)

                if "Order Header" in item.Subject:
                    new_file_name = f"{report_date} - Daily Orders - Zenith - Order Headers.csv"
                    attachment_path = os.path.join(attachments_dir, new_file_name)

                # Save the attachment
                attachment.SaveAsFile(attachment_path)
                print(f"Saved attachment: {new_file_name} from email: {item.Subject}")
        else:
            print(f"No attachments in email: {item.Subject}")

    except Exception as e:
        print(f"Error processing email: {e}")

print(f"Attachments downloaded to {attachments_dir}")
# Out:
# Processing email: Zenith Order Line Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Saved attachment: 2025-02-02 - Daily Orders - Zenith - Order Lines.csv from email: Zenith Order Line Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Processing email: Zenith Order Header Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Saved attachment: 2025-02-02 - Daily Orders - Zenith - Order Headers.csv from email: Zenith Order Header Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Processing email: Zenith Order Line Data - 2025-01-31 18:00:00.000 to 2025-02-01 17:59:59.997
# Saved attachment: 2025-02-01 - Daily Orders - Zenith - Order Lines.csv from email: Zenith Order Line Data - 2025-01-31 18:00:00.000 to 2025-02-01 17:59:59.997
# Processing email: Zenith Order Header Data - 2025-01-31 18:00:00.000 to 2025-02-01 17:59:59.997
# ...

# %%
import win32com.client
import os
from datetime import datetime

# Connect to Outlook
outlook = win32com.client.Dispatch("Outlook.Application")
namespace = outlook.GetNamespace("MAPI")

# Access the shared mailbox
email_id = 'automationpx-team@solenis.com'  # Replace with the actual email ID
shared_mailbox = namespace.Folders[email_id]

# Access the Inbox of the shared mailbox
inbox = shared_mailbox.Folders['Inbox']  # Access Inbox

# Directory to save attachments
attachments_dir = r'C:\Users\A803377\Emails'  # Replace with your local path
os.makedirs(attachments_dir, exist_ok=True)

# Number of emails to check
num_emails_to_check = 

# Collect the first 'num_emails_to_check' emails
emails = inbox.Items
emails.Sort("[ReceivedTime]", True)  # Sort emails by received time (most recent first)

# Loop through the first 'num_emails_to_check' emails
for i, item in enumerate(emails):
    if i >= num_emails_to_check:
        break
    
    try:
        print(f"Processing email: {item.Subject}")

        if item.Attachments.Count > 0:
            report_date = item.ReceivedTime.strftime("%Y-%m-%d")  # Get the received date

            for attachment in item.Attachments:
                attachment_name = attachment.FileName
                attachment_path = os.path.join(attachments_dir, attachment_name)

                # Logic for renaming files based on email subject
                if "Order Line" in item.Subject:
                    new_file_name = f"{report_date} - Daily Orders - Zenith - Order Lines.csv"
                    attachment_path = os.path.join(attachments_dir, new_file_name)

                if "Order Header" in item.Subject:
                    new_file_name = f"{report_date} - Daily Orders - Zenith - Order Headers.csv"
                    attachment_path = os.path.join(attachments_dir, new_file_name)

                # Save the attachment
                attachment.SaveAsFile(attachment_path)
                print(f"Saved attachment: {new_file_name} from email: {item.Subject}")
        else:
            print(f"No attachments in email: {item.Subject}")

    except Exception as e:
        print(f"Error processing email: {e}")

print(f"Attachments downloaded to {attachments_dir}")
# Out:
# Processing email: Zenith Order Line Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Saved attachment: 2025-02-02 - Daily Orders - Zenith - Order Lines.csv from email: Zenith Order Line Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Processing email: Zenith Order Header Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Saved attachment: 2025-02-02 - Daily Orders - Zenith - Order Headers.csv from email: Zenith Order Header Data - 2025-02-01 18:00:00.000 to 2025-02-02 17:59:59.997
# Processing email: Scheduled Report: US Domain - KPIs1
# Saved attachment: 2025-02-02 - Daily Orders - Zenith - Order Headers.csv from email: Scheduled Report: US Domain - KPIs1
# Processing email: Scheduled Report: EU Domain - KPIs1
# Saved attachment: 2025-02-02 - Daily Orders - Zenith - Order Headers.csv from email: Scheduled Report: EU Domain - KPIs1
# Processing email: Zenith Order Line Data - 2025-01-31 18:00:00.000 to 2025-02-01 17:59:59.997
# ...

# %%
import os
import json
import requests
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

DIR_PATH = r'C:\Users\A803377\tmp_cs_reporting'

valid_email_ids = [
    "I.T@zhgplc.com",
    "reports-noreply@five9.com",
]

auth_url = "https://login.microsoftonline.com/c84d9378-ad95-4040-9258-2ed1ae880ded/oauth2/v2.0/token"
payload = 'client_id=0a665890-4890-4c77-99a0-365f0044a94d&scope=offline_access%20Mail.ReadWrite%20Mail.send&client_secret=dX38Q~EY-jpwzORoMDlSGJcClvJoILtGlOM-Rdz6&grant_type=refresh_token&refresh_token=0.AXgAeJNNyJWtQECSWC7RrogN7ZBYZgqQSHdMmaA2XwBEqU14AO8.AgABAwEAAADnfolhJpSnRYB1SVj-Hgd8AgDs_wUA9P9Kd_GXcibEUoyDOsWIVt8n7nVtGQMZz_D8-dv_fGkX_DEffMJRZvntj7k_tgtTYqzhW8IC6TELPaPMVjGOhNaGLZhRM9VP6O0sfRvUKZVE2FbzxZEDt5JCOm_xhcnaHeBXwETE16Hx69eqyfakS3Ad3dHXHgS86EE88reXXaYDf3d8BjrHut3lD6i_eBzHO25Jsj8oVVeMJ-HvZIhvvs5LNjwI2LGLZhvyeyLi4MYbOHXK1IfxHXtbeBUuodHNI1svlZFAv8T6sad7ArfzAZHWePwKt80wrH4Mk-gfWYv-Yk6CW5SG8Zh-FF6LtdmhLxd6JEKMhaGapNcbx1Hx0Lly49MBRWLZPofbu-MND_l_cWBg7QxEVIP6SCqHV0W-inmEMRj5GrNB7bDF54SbAkw6U7sUvsHwiIKTtH6xUoXMMpHzAYexP_yTtuutZy5hReAlJlLrsABJEkxIIgBKbhcx8zT1vyXthBPwEZOCOOTA89Ip9Tt-GWeW_S-rATBudbQtA4FNMbGlUUfkAYbDZQj6eOYRlOJ3Q6idy3DxS0m1HR94NOXlj__pbPCY7aB70ad_1AfNK_kHCAi5JmbnScD8lCLeCtC3V8DkvbAjMshuui_2bUy2tJZ_R3DiG0ou5tL8gXHC_4ZXL3xRaCYTfhLrIbJPFb5yz2bHcOJrxI9KN8ZYnPNI0CaURzg9PHjwWouqXEE'
headers = {
    'Content-Type': 'application/x-www-form-urlencoded',
    'Cookie': 'fpc=AoOHX6I2vRtBiukIcxN8GqEtcR5iAQAAAAzS890OAAAA;stsservicecookie=estsfd; x-ms-gateway-slice=estsfd' 
}

response = requests.post(auth_url, headers=headers, data=payload)
result = response.json()
# Print result['access_token']

endpoint = f"https://graph.microsoft.com/v1.0/me/messages"
for day in range(0, 10):
    received_date = (datetime.now()-timedelta(days=day)).strftime("%Y-%m-%d")
    params = {
        "$filter": f"ReceivedDateTime ge {received_date}"
    }

    response = requests.get(endpoint, headers={'Authorization': 'Bearer ' + result['access_token']}, params=params)
    response.raise_for_status()

    response_data = response.json()
    #print(json.dumps(response.json(), indent=4))

    for each in response_data["value"]:
        sender_email_id = each['sender']['emailAddress']['address']
        if sender_email_id not in valid_email_ids:
            continue

        msg_id = each["id"]
        endpoint_attachment = endpoint + "/" + msg_id + "/attachments/"
        response = requests.get(
            endpoint_attachment, headers={'Authorization': 'Bearer ' + result['access_token']}
        )
        response.raise_for_status()  # Raise an exception if request fails
        files_json = response.json().get('value')
        for each in files_json:
            email_name = each["name"]
            attachment_id = files_json[-1].get('id')
            endpoint_attachment_file = endpoint_attachment + "/" + attachment_id + "/$value"
            response = requests.get(
                url=endpoint_attachment_file,
                headers={'Authorization': 'Bearer ' + result['access_token']},
                stream=True
            )
            with open(f"{DIR_PATH}{email_name}", "wb+") as file:
                for chunk in response.iter_content(chunk_size=20*1024*1024):
                    file.write(chunk)

            new_file_name = ""
            if email_name.endswith(".csv"):
                df = pd.read_csv(f"{DIR_PATH}{email_name}")
            else:
                df = pd.read_excel(f"{DIR_PATH}{email_name}", skiprows=14)
                df = df.fillna("")
                df.drop(df.columns[df.columns.str.contains('unnamed', case=False)], axis=1, inplace=True)

                df["Case Owner"] = df["Case Owner"].replace("", np.nan)
                df = df.dropna(axis=0, subset=["Case Owner"])

                transform_cols_list = ["Opened Date", "Closed Date"]
                for transform_col in transform_cols_list:
                        df[transform_col] = pd.to_datetime(df[transform_col], dayfirst=True).dt.strftime("%Y-%m-%d")

                columns = list(df.columns)
                if "Date/Time Opened" in columns:
                    df["Date/Time Opened"] = pd.to_datetime(df["Date/Time Opened"], format="%d/%m/%Y %H:%M")
                        
                records_list = df.to_dict(orient="records")
                for row in records_list:
                    for key_name, key_value in row.items():
                        key_value = str(key_value)
                        if key_value.endswith(".0"):
                            row[key_name] = key_value.split(".")[0]

                new_file_name = email_name.replace(".xlsx", ".csv").replace(".xls", ".csv")
                df = pd.DataFrame(records_list)

            if "US Domain" in email_name:
                report_date = df["DATE"].to_list()[0] if df["DATE"].to_list() else ""
                report_date = report_date.replace("/", "-")
                new_file_name = f"{report_date} - Daily Calls - Five9 US Domain.csv"
            if "EU Domain" in email_name:
                report_date = df["DATE"].to_list()[0] if df["DATE"].to_list() else ""
                report_date = report_date.replace("/", "-")
                new_file_name = f"{report_date} - Daily Calls - Five9 EU Domain.csv"
            if "Order Line" in email_name:
                report_date = df["Date"].to_list()[0] if df["Date"].to_list() else ""
                report_date = datetime.strptime(report_date, "%d/%m/%Y").strftime("%Y-%m-%d")
                new_file_name = f"{report_date} - Daily Orders - Zenith - Order Lines.csv"
            if "Order Header" in email_name:
                report_date = df["Date"].to_list()[0] if df["Date"].to_list() else ""
                report_date = datetime.strptime(report_date, "%d/%m/%Y").strftime("%Y-%m-%d")
                new_file_name = f"{report_date} - Daily Orders - Zenith - Order Headers.csv"

            if new_file_name:
                print(new_file_name)
                df.to_csv(f"{DIR_PATH}{new_file_name}", index=False)
                os.remove(f"{DIR_PATH}{email_name}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_53400/3045962948.py in <module>
#      31     }
#      32
# ---> 33     response = requests.get(endpoint, headers={'Authorization': 'Bearer ' + result['access_token']}, params=params)
#      34     response.raise_for_status()
#      35
#
# KeyError: 'access_token'

# %%
from exchangelib import Credentials, Account, Configuration, DELEGATE
import os

# Replace with your email and password
email_address = 'i700282@solenis.com'  # The email ID to access
password = '1eCV2V3de(Zk3/'  # Replace with your password

# Set up credentials and account
credentials = Credentials(email_address, password)
account = Account(email_address, credentials=credentials, autodiscover=True, access_type=DELEGATE)

# Directory to save attachments
attachments_dir = r'C:\Users\A803377\Emails'  # Replace with your local path
os.makedirs(attachments_dir, exist_ok=True)

# Get the first 10 emails from the inbox
for item in account.inbox.all().order_by('-datetime_received')[:10]:
    try:
        print(f"Processing email: {item.subject}")

        if item.attachments:
            for attachment in item.attachments:
                attachment_path = os.path.join(attachments_dir, attachment.name)
                
                # Save the attachment
                with open(attachment_path, 'wb') as f:
                    f.write(attachment.content)
                print(f"Saved attachment: {attachment.name} from email: {item.subject}")
        else:
            print(f"No attachments in email: {item.subject}")

    except Exception as e:
        print(f"Error processing email: {e}")

print(f"Attachments downloaded to {attachments_dir}")
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26716/432483195.py in <module>
#       8 # Set up credentials and account
#       9 credentials = Credentials(email_address, password)
# ---> 10 account = Account(email_address, credentials=credentials, autodiscover=True, access_type=DELEGATE)
#      11
#      12 # Directory to save attachments
#
# ~\Anaconda3\lib\site-packages\exchangelib\account.py in __init__(self, primary_smtp_address, fullname, access_type, autodiscover, credentials, config, locale, default_timezone)
#     177             else:
#     178                 auth_type, retry_policy, version, max_connections = None, None, None, None
# --> 179             self.ad_response, self.protocol = Autodiscovery(
#     180                 email=primary_smtp_address, credentials=credentials
#     181             ).discover()
#
# ...

# %%
pip install exchangelib
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#    ---------------------------------------- 570.1/570.1 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\A803377\AppData\Roaming\Python\Python39\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\A803377\AppData\Roaming\Python\Python39\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
# ...

# %%
import requests

class FuzeAPIClient:
    def __init__(self):
        self.base_url = 'https://rest.data.fuze.com/'
        self.headers = {
            'Authorization': 'Bearer 2.jaFEhblYwvUEH0B.dXNlcjpid1paR1Z3aWZmOkVmU0RUeUdNRGE'
        }
        self.session = requests.Session()
        
        try:
            # Test connection
            response = self.session.get(self.base_url + 'ping', headers=self.headers, verify=True)  # Use verify=True in production
            response.raise_for_status()
            print("Connected to Fuze API successfully.")
        except requests.exceptions.SSLError as ssl_err:
            print(f"SSL Error: {ssl_err}")
        except requests.exceptions.RequestException as req_err:
            print(f"Request Error: {req_err}")

# Example usage
client = FuzeAPIClient()
# Out:
# Connected to Fuze API successfully.

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import json
import requests
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Directory to save attachments
DIR_PATH = r'C:\Users\A803377\Emails\\'  # Replace with your local path
# os.makedirs(attachments_dir, exist_ok=True)

# DIR_PATH = 'C:\Users\A803377\Emails\tmp_cs_reporting'

valid_email_ids = [
    "I.T@zhgplc.com",
    "reports-noreply@five9.com"
    "automationpx-team@solenis.com",
    
]
auth_url = "https://login.microsoftonline.com/c84d9378-ad95-4040-9258-2ed1ae880ded/oauth2/v2.0/token"

payload = {
    'client_id': '0a665890-4890-4c77-99a0-365f0044a94d',
    'scope': 'offline_access Mail.ReadWrite Mail.send',
    'client_secret': 'dX38Q~EY-jpwzORoMDlSGJcClvJoILtGlOM-Rdz6',
    'grant_type': 'refresh_token',
    'refresh_token': '0.AXgAeJNNyJWtQECSWC7RrogN7ZBYZgqQSHdMmaA2XwBEqU39AO8.AgABAwEAAADW6jl31mB3T7ugrWTT8pFeAwDs_wUA9P-q-7k0kXh6jxN-pqP7UFHoW2kYuWSDrnBvEkMnPf-pNysCUxddoD7HN_LGyP5Gg6wovzxf7cyQgnaFRmFOLcybanOhSNEyB3uyPIN6_HZVyTlMbl4OJ88uRn9o-7_I1fir0i10hM1lbpiK1xXgF0LOHOP6Dyu5ZhqmuDRS3AiigP4YI-aIyMBYXpI9lFpC1d1mc3t7KUJ7At3CtbpcyH8j1PMthTPBkKYUMyPCMPINTle25CCA14NmRDWfLJQFUDfb9bpuTrxoLLXVt0611ASu4C2F6Ud_CGuu1YxLA9HQrNHBnKnPYJUZ0ZzGK9e0m5m90-GQRlY4kTteHR3bti1lALt6uHqdVXKMHW5jbiNegy8gjNFrVjdkJtGyZBzWAsPa_KMUakxMLXxYXWPw-3YvpEvkoJcwDGNg3p2GT0k1X7nIo9-g1Uo3idHi8PM_Z7JKDYt1yaxdW1QDr3rKbzbf2VpUtURSNSHmxLklllHd6jZCG-sw8mGqlljWs_DqaMRVpK1mVMMKkZKxuY4dQAUOVSpDtuAz2Je2tA9_748tsTGVTmuUnO3bKvdK5_dw3e5U08nXj3LfbHm1ScertIiymYILFCgvYQYVgW7NlHUZr2bJ7r40cJntgxk5qmfTwsMrrgSTXYJM5cS_Z5I78i-E1qRerYbrYROWjTC7vXSGWSqKgvxDRwYVqZODmlo5llvY8xAT'
}

headers = {
    'Content-Type': 'application/x-www-form-urlencoded',
    'Cookie': 'fpc=Ar0v57S0EjlEiy3IsTcXZPMtcR5iAQAAAJpkrd4OAAAA;stsservicecookie=estsfd; x-ms-gateway-slice=estsfd' 
}


response = requests.post(auth_url, headers=headers, data=payload)
result = response.json()
# Print result['access_token']

endpoint = f"https://graph.microsoft.com/v1.0/me/messages"

for day in range(0, 36):
    received_date = (datetime.now()-timedelta(days=day)).strftime("%Y-%m-%d")
    params = {
        "$filter": f"ReceivedDateTime ge {received_date}"
    }

    response = requests.get(endpoint, headers={'Authorization': 'Bearer ' + result['access_token']}, params=params)
    response.raise_for_status()

    response_data = response.json()
    #print(json.dumps(response.json(), indent=4))

    for each in response_data["value"]:
        sender_email_id = each['sender']['emailAddress']['address']
        if sender_email_id not in valid_email_ids:
            continue

        msg_id = each["id"]
        endpoint_attachment = endpoint + "/" + msg_id + "/attachments/"
        response = requests.get(
            endpoint_attachment, headers={'Authorization': 'Bearer ' + result['access_token']}
        )
        response.raise_for_status()  # Raise an exception if request fails
        files_json = response.json().get('value')
        for each in files_json:
            email_name = each["name"]
            attachment_id = files_json[-1].get('id')
            endpoint_attachment_file = endpoint_attachment + "/" + attachment_id + "/$value"
            response = requests.get(
                url=endpoint_attachment_file,
                headers={'Authorization': 'Bearer ' + result['access_token']},
                stream=True
            )
            with open(f"{DIR_PATH}{email_name}", "wb+") as file:
                for chunk in response.iter_content(chunk_size=20*1024*1024):
                    file.write(chunk)

            new_file_name = ""
            if email_name.endswith(".csv"):
                df = pd.read_csv(f"{DIR_PATH}{email_name}")
            else:
                df = pd.read_excel(f"{DIR_PATH}{email_name}", skiprows=14)
                df = df.fillna("")
                df.drop(df.columns[df.columns.str.contains('unnamed', case=False)], axis=1, inplace=True)

                df["Case Owner"] = df["Case Owner"].replace("", np.nan)
                df = df.dropna(axis=0, subset=["Case Owner"])

                transform_cols_list = ["Opened Date", "Closed Date"]
                for transform_col in transform_cols_list:
                        df[transform_col] = pd.to_datetime(df[transform_col], dayfirst=True).dt.strftime("%Y-%m-%d")

                columns = list(df.columns)
                if "Date/Time Opened" in columns:
                    df["Date/Time Opened"] = pd.to_datetime(df["Date/Time Opened"], format="%d/%m/%Y %H:%M")
                        
                records_list = df.to_dict(orient="records")
                for row in records_list:
                    for key_name, key_value in row.items():
                        key_value = str(key_value)
                        if key_value.endswith(".0"):
                            row[key_name] = key_value.split(".")[0]

                new_file_name = email_name.replace(".xlsx", ".csv").replace(".xls", ".csv")
                df = pd.DataFrame(records_list)

#             if "US Domain" in email_name:
#                 report_date = df["DATE"].to_list()[0] if df["DATE"].to_list() else ""
#                 report_date = report_date.replace("/", "-")
#                 new_file_name = f"{report_date} - Daily Calls - Five9 US Domain.csv"
#             if "EU Domain" in email_name:
#                 report_date = df["DATE"].to_list()[0] if df["DATE"].to_list() else ""
#                 report_date = report_date.replace("/", "-")
#                 new_file_name = f"{report_date} - Daily Calls - Five9 EU Domain.csv"
            if "Order Line" in email_name:
                report_date = df["Date"].to_list()[0] if df["Date"].to_list() else ""
                report_date = datetime.strptime(report_date, "%d/%m/%Y").strftime("%Y-%m-%d")
                new_file_name = f"{report_date} - Daily Orders - Zenith - Order Lines.csv"
            if "Order Header" in email_name:
                report_date = df["Date"].to_list()[0] if df["Date"].to_list() else ""
                report_date = datetime.strptime(report_date, "%d/%m/%Y").strftime("%Y-%m-%d")
                new_file_name = f"{report_date} - Daily Orders - Zenith - Order Headers.csv"

            if new_file_name:
                print(new_file_name)
                df.to_csv(f"{DIR_PATH}{new_file_name}", index=False)
                os.remove(f"{DIR_PATH}{email_name}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35924/991352315.py in <module>
#      49     }
#      50
# ---> 51     response = requests.get(endpoint, headers={'Authorization': 'Bearer ' + result['access_token']}, params=params)
#      52     response.raise_for_status()
#      53
#
# KeyError: 'access_token'

# %%
import pandas as pd
import os

# Specify the directory containing the Excel files
folder_path = r'C:\Users\A803377\Five9'  # Update this path
output_file = r'C:\Users\A803377\Five9\FinalCOncat_file.xlsx'  # Update this path

# Initialize a list to hold the dataframes
dataframes = []

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_excel(file_path)
        dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Write the combined dataframe to a new Excel file
combined_df.to_excel(output_file, index=False)

print(f'All Excel files in {folder_path} have been combined into {output_file}.')

# %%
import pandas as pd
import os

# Specify the directory containing the CSV files
folder_path = r'C:\Users\A803377\Five9'  # Update this path
output_file = r'C:\Users\A803377\Five9\FinalCOncat_file.csv'  # Update this path

# Initialize a list to hold the dataframes
dataframes = []

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Write the combined dataframe to a new CSV file
combined_df.to_csv(output_file, index=False)

print(f'All CSV files in {folder_path} have been combined into {output_file}.')
# Out:
# All CSV files in C:\Users\A803377\Five9 have been combined into C:\Users\A803377\Five9\FinalCOncat_file.csv.
