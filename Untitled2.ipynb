# %%
import pyodbc
cnxn = pyodbc.connect('Driver=SQL Server;Server=NAAZUREEDWS01;Database=TableauDB;Trusted_Connection=yes;')
#cursor = cnxn.cursor()
#cursor.execute("SELECT top 10 * FROM dbo.financemaster")

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
data = pd.read_sql_query("select top 10 * from [LIB_EDW_RTP].[dbo].[ZZZ_PAID_ON_TIME_INVOICES] ORDER BY [Posting Date] DESC", cnxn)

# %%
data
# Out:
#   DATA_EXTRACT_DATE Client Fiscal Year Company Accounting Document  \
# 0        2022-02-01    020        2022    0612          5100026806
# 1        2022-02-01    020        2022    0612          5100026804
# 2        2022-02-01    020        2022    0612          5100026807
# 3        2022-02-01    020        2022    0612          5100026784
# 4        2022-02-01    020        2022    0612          5100026785
# 5        2022-02-01    020        2022    0612          5100026805
# 6        2022-02-01    020        2022    0612          5100026781
# 7        2022-02-01    020        2022    0612          5100026782
# 8        2022-02-01    020        2022    0612          5100026803
# 9        2022-02-01    020        2022    0612          5100026777
#
#   Accounting Document Line Posting Date Document Date Clearing Date  \
# 0                      001   2022-01-31    2021-12-13    2022-02-01
# 1                      001   2022-01-31    2021-12-20    2022-02-01
# ...

# %%
data1 = pd.read_sql_query("select top 1000 * from [LIB_EDW_RTP].[dbo].[ZZZ_INVOICES_RECORDED] ORDER BY [Posting Date] DESC", cnxn)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   DATA_EXTRACT_DATE                   1000 non-null   object
#  1   Client                              1000 non-null   object
#  2   Fiscal Year                         1000 non-null   object
#  3   Company                             1000 non-null   object
#  4   Accounting Document                 1000 non-null   object
#  5   Accounting Document Line            1000 non-null   object
#  6   Posting Date                        1000 non-null   object
#  7   Document Date                       1000 non-null   object
#  8   Clearing Date                       0 non-null      object
#  9   Clearing Date Text                  1000 non-null   object
#  10  Vendor                              1000 non-null   object
# ...

# %%
d9['Due Date']= pd.to_datetime(d9['Due Date'])
d9['DATA_EXTRACT_DATE']= pd.to_datetime(d9['DATA_EXTRACT_DATE'])
# Out:
# C:\Users\A803377\AppData\Local\Temp/ipykernel_14008/2543354696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d9['Due Date']= pd.to_datetime(d9['Due Date'])
# C:\Users\A803377\AppData\Local\Temp/ipykernel_14008/2543354696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d9['DATA_EXTRACT_DATE']= pd.to_datetime(d9['DATA_EXTRACT_DATE'])

# %%
d9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 857 entries, 0 to 999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   DATA_EXTRACT_DATE                   857 non-null    datetime64[ns]
#  1   Client                              857 non-null    object
#  2   Fiscal Year                         857 non-null    object
#  3   Company                             857 non-null    object
#  4   Accounting Document                 857 non-null    object
#  5   Accounting Document Line            857 non-null    object
#  6   Posting Date                        857 non-null    object
#  7   Document Date                       857 non-null    object
#  8   Clearing Date                       0 non-null      object
#  9   Clearing Date Text                  857 non-null    object
#  10  Vendor                              857 non-null    object
# ...

# %%
[ZZZ_INVOICES_RECORDED]

# %%
date = data1.groupby('DATA_EXTRACT_DATE')

# %%
d9= date.get_group('2022-01-19')

# %%
d9.sum(axis = 1, skipna = True)
d9['Group Currency Amount'].sum()
# Out:
# C:\Users\A803377\AppData\Local\Temp/ipykernel_14008/588268988.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d9.sum(axis = 1, skipna = True)
# -8477933.186843

# %%
df=pd.DataFrame()

# %%
df['Difference'] = d9['Due Date']-d9['DATA_EXTRACT_DATE']

# %%
d9['Due Date']
# Out:
# 0     2022-01-11
# 1     2022-01-07
# 2     2022-01-14
# 3     2021-12-31
# 4     2021-11-10
#          ...
# 995   2022-02-28
# 996   2022-02-12
# 997   2022-01-29
# 998   2022-04-16
# 999   2022-04-14
# Name: Due Date, Length: 857, dtype: datetime64[ns]

# %%
d9['DATA_EXTRACT_DATE']
# Out:
# 0     2022-01-19
# 1     2022-01-19
# 2     2022-01-19
# 3     2022-01-19
# 4     2022-01-19
#          ...
# 995   2022-01-19
# 996   2022-01-19
# 997   2022-01-19
# 998   2022-01-19
# 999   2022-01-19
# Name: DATA_EXTRACT_DATE, Length: 857, dtype: datetime64[ns]

# %%
df
# Out:
#     Difference
# 0      -8 days
# 1     -12 days
# 2      -5 days
# 3     -19 days
# 4     -70 days
# ..         ...
# 995    40 days
# 996    24 days
# 997    10 days
# 998    87 days
# 999    85 days
#
# [857 rows x 1 columns]

# %%
IF [Invoice aging]<=0 THEN 'Due'
ELSEIF [Invoice aging]>0 THEN 'Not due'
END

# %%
data10 = pd.read_sql_query("select top 30000* from [LIB_EDW_RTP].[dbo].[ZZZ_INVOICES_RECORDED] WHERE [Fiscal Year]>=2021 ORDER BY [Posting Date] DESC", cnxn)

# %%
data10
# Out:
#       DATA_EXTRACT_DATE Client Fiscal Year Company Accounting Document  \
# 0            2022-01-20    020        2022    0410          5100455757
# 1            2022-01-20    020        2022    1800          5100074450
# 2            2022-01-20    020        2022    0911          5100025442
# 3            2022-01-20    020        2022    0612          5100026477
# 4            2022-01-20    020        2022    0869          5100186492
# ...                 ...    ...         ...     ...                 ...
# 29995        2022-01-15    020        2022    1020          5101030724
# 29996        2022-01-15    020        2022    1020          5101030739
# 29997        2022-01-15    020        2022    0900          5100004171
# 29998        2022-01-15    020        2022    0900          5100004176
# 29999        2022-01-15    020        2022    5500          5100143178
#
#       Accounting Document Line Posting Date Document Date Clearing Date  \
# ...

# %%
data10.sum(axis = 1, skipna = True)
data10['Group Currency Amount'].sum()
# Out:
# -220298232.97459403

# %%
data10 = pd.read_sql_query("select top 100 * from [TableauDB].[rpt].[Vw_OpenOrdersDailyReport] ", cnxn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]The SELECT permission was denied on the object 'Reporting Exchange Rate Euro', database 'EDWDBReport', schema 'rpt'. (229) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18424/1971138857.py in <module>
# ----> 1 data10 = pd.read_sql_query("select top 100 * from [TableauDB].[rpt].[Vw_OpenOrdersDailyReport] ", cnxn)
#
# ...

# %%
data10
# Out:
#       DATA_EXTRACT_DATE Client Fiscal Year Company Accounting Document  \
# 0            2022-01-20    020        2022    0410          5100455739
# 1            2022-01-20    020        2022    0410          5100455748
# 2            2022-01-20    020        2022    1800          5100074436
# 3            2022-01-20    020        2022    1800          5100074448
# 4            2022-01-20    020        2022    0410          5100455750
# ...                 ...    ...         ...     ...                 ...
# 99995        2022-01-16    020        2022    0494          1900020186
# 99996        2022-01-16    020        2022    7863          5100022353
# 99997        2022-01-09    020        2022    0612          5100026037
# 99998        2022-01-10    020        2022    0410          2800049607
# 99999        2022-01-10    020        2022    0410          2800049681
#
#       Accounting Document Line Posting Date Document Date Clearing Date  \
# ...

# %%
num = pd.read_sql_query("select -(SUM([Group Currency Amount])) from [LIB_EDW_RTP].[dbo].[ZZZ_INVOICES_RECORDED] as Value WHERE [DATA_EXTRACT_DATE]>='2022-1-2' ", cnxn)

# %%
SELECT SUM(Quantity) AS TotalItemsOrdered FROM OrderDetails

# %%
num
# Out:
#
# 0  7.291770e+09

# %%
SELECT
DATA_EXTRACT_DATE
,ZZZ.Client
,[Fiscal Year]
,ZZZ.Company
,[Accounting Document]
,[Accounting Document Line]
,[Posting Date]
,[Document Date]
,[Clearing Date]
,[Clearing Date Text]
,[Baseline Date]
,ZZZ.Vendor
,[Special GL Indicator]
,[Document Type]
,[Master Reconciliation Account Key]
,[Master Reconciliation Account]
,[Posting Reconciliation Account Key]
,[Posting Reconciliation Account]
,[Purchasing Document Number]
,[Item Text]
,[Reference Document Number]
,[Payment Block]
,[Payment Terms]
,[Clearing Document Number]
,[Payment Method]
,[Assignment Number]
,[Posting Key]
,[Source Table]
,ZZZ.[Controlling Area]
,[Profit Center Key]
,[Due Date]
,[User Id]
,ZZZ.[Chart of Accounts]
,[Group Currency]
,[Group Currency Amount]
,[Company Currency]
,[Company Currency Amount]
,[Document Currency]
,[Document Currency Amount]
,[Transaction Type]
,[Vendor Company Key]
,[Entry Date]
,[RKPF Reference Key]
,[Tax on Sales]
,[Country Key]
,ZZZ.[Vendor Account Group]
,ZZZ.[Payment Supplement Method]
,ZZZ.[Critical Vendor]
,ZZZ.[Vendor Name]
,C.[Company Name]
,C.City
,C.Country
,C.Currency
,C.[Global Region]
,V.[Display Vendor]
,ZZZ.[Debit/Credit Indicator]
,EX.[BP FX RATE]
,EX.FromCurrency FROM LIB_EDW_RTP.dbo.ZZZ_INVOICES_RECORDED ZZZ
LEFT OUTER JOIN LIB_EDW_RTP.dim.Company C
ON ZZZ.Client = C.Client
AND ZZZ.Company = C.Company
AND ZZZ.[Chart of Accounts] = C.[Chart Of Accounts]
AND ZZZ.[Controlling Area] = C.[Controlling Area]
LEFT OUTER JOIN LIB_EDW_RTP.dim.Vendor V
ON ZZZ.Client = V.Client
AND ZZZ.Vendor = V.Vendor left join LIB_EDW_RTP.[RPT].[Reporting Exchange Rate] EX
ON EX.FromCurrency=[Document Currency]
and EX.[Fiscal Year Number] =[Fiscal Year]
And case when len(cast(EX.[Calendar Month Number] as nvarchar))=2
then EX.[Calendar Month Number]
else concat(0,EX.[Calendar Month Number])
end =substring(cast(ZZZ.[Posting Date] as nvarchar),6,2)

# %%
5589085 + 2825997
# Out:
# 8415082
