# %%
# !pip install fast-to-sql

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport

import matplotlib 
from matplotlib import pyplot as plt
from matplotlib import style
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
# df= pd.read_excel(r"C:\Users\A803377\Downloads\Cost Adder 2022.xls")
df
# Out:
#                  Concat Reporting_Line ProfitCenterSBUDesc  COGS Adder Review  \
# 0                 AP_CS          AP_CS                               0.000000
# 1                 AP_CS          AP_CS                               0.000000
# 2                 AP_CS          AP_CS                               0.000000
# 3                 AP_CS          AP_CS                               0.000000
# 4                 AP_CS          AP_CS                               0.000000
# ...                 ...            ...                 ...                ...
# 2277  NA_ISWet Strength          NA_IS        Wet Strength           0.061822
# 2278  NA_ISWet Strength          NA_IS        Wet Strength           0.061822
# 2279  NA_ISWet Strength          NA_IS        Wet Strength           0.061822
# 2280  NA_ISWet Strength          NA_IS        Wet Strength           0.061822
# 2281  NA_ISWet Strength          NA_IS        Wet Strength           0.061822
#
#      Fiscal Period
# ...

# %%
df[['Concat', 'Reporting_Line', 'ProfitCenterSBUDesc', 
       'Fiscal Period']] = df[[ 'Concat', 'Reporting_Line', 'ProfitCenterSBUDesc', 
       'Fiscal Period']].astype('string').replace('\.0', '', regex=True)
df[['Concat', 'Reporting_Line', 'ProfitCenterSBUDesc', 
       'Fiscal Period']] = df[[ 'Concat', 'Reporting_Line', 'ProfitCenterSBUDesc', 
       'Fiscal Period']].replace(np.nan, '', regex=True)
df[['COGS Adder Review']] = df[['COGS Adder Review']].replace(np.nan, 0.0, regex=True)

# %%
df= pd.read_excel(r'C:\Users\A803377\Downloads\SQL Data - 27th Feb.xlsx')
df
# Out:
#                                         CONCAT Controlling Area   Document  \
# 0       20221102397054135775808314302855700040             ASHI  135775808
# 1       20221102397054135775808318320105700016             ASHI  135775808
# 2       20221102397054135775808430992236700041             ASHI  135775808
# 3       20221102397054135775808598992655700041             ASHI  135775808
# 4        2022110239705513577580967320106700004             ASHI  135775809
# ...                                        ...              ...        ...
# 371909    202352000000491386785904996081700048             ASHI  138678590
# 371910   2023520000004913867859065381014700016             ASHI  138678590
# 371911  20235200000049138678590114381049700016             ASHI  138678590
# 371912    202351000060011386789951993286712012             ASHI  138678995
# 371913   2022113222730233222730662992511728518             ASHI  322273066
#
#         Line Item Posting Date            Object Cost Element Key  \
# ...

# %%
# df= pd.read_csv(r'C:\Users\A803377\Downloads\SQL Data - 27th Feb - Copy.csv')
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371914 entries, 0 to 371913
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CONCAT                      371914 non-null  object
#  1   Controlling Area            371914 non-null  object
#  2   Document                    371914 non-null  int64
#  3   Line Item                   371914 non-null  int64
#  4   Posting Date                371914 non-null  datetime64[ns]
#  5   Object                      371914 non-null  object
#  6   Cost Element Key            371914 non-null  object
#  7   Cost Element                371914 non-null  int64
#  8   Cost Center                 371914 non-null  int64
#  9   Cost Center Key             371914 non-null  object
#  10  Actual Document Amount      371914 non-null  float64
#  11  Actual Company Amount       371914 non-null  float64
# ...

# %%
print('NR:',df['$LC Final Rev Diff'].sum())
print('GP:',df['$LC COGS Diff'].sum())
# Out:
# NR: 59032.36579799652
# GP: 201178575.65168905

# %%
df[['CONCAT','Controlling Area','Document', 'Line Item','Object', 'Cost Element Key', 'Cost Element', 'Cost Center','Cost Center Key', 'Company Currency',
'Document Currency','Group Currency','Company', 'Functional Area',
       'Fiscal Year', 'Fiscal Period', 'Reference Document Number',
       'Purchasing Document Number', 'Vendor', 'Vendor Name',
       'PO_VendorNumber', 'PO_VendorName', 'Cost Center Name',
       'Cost Element Name', 'Cost Group', 'Cost Group formula',
       'Document Type', 'Document Type Description', 'New Vendor Names',
       'Function', 'Sub-Function', 'Company Name', 'Region', 'Month']] = df[['CONCAT','Controlling Area','Document', 'Line Item','Object', 'Cost Element Key', 'Cost Element', 'Cost Center','Cost Center Key', 'Company Currency',
'Document Currency','Group Currency','Company', 'Functional Area',
       'Fiscal Year', 'Fiscal Period', 'Reference Document Number',
       'Purchasing Document Number', 'Vendor', 'Vendor Name',
       'PO_VendorNumber', 'PO_VendorName', 'Cost Center Name',
       'Cost Element Name', 'Cost Group', 'Cost Group formula',
       'Document Type', 'Document Type Description', 'New Vendor Names',
       'Function', 'Sub-Function', 'Company Name', 'Region', 'Month']].astype('string').replace('\.0', '', regex=True)

# %%
df[['Firms', 'Invoice #', 'Invoice Date', 'Matter',
       'Classification', 'Projects', 'Regions', 'Countries',
       'Column1', 'Notes','Invoice Amount', 'Owner' ]] = df[['Firms', 'Invoice #','Invoice Date', 'Matter',
       'Classification', 'Projects', 'Regions', 'Countries',
       'Column1', 'Notes','Invoice Amount', 'Owner']].astype('string').replace('\.0', '', regex=True)

# df[[ 'Invoice Date', 'Month Work Performed ']] = pd.to_datetime(df[[ 'Invoice Date', 'Month Work Performed ']]).dt.strftime('%Y-%m-%d')

# df["Invoice Date"] = pd.to_datetime(df["Invoice Date"]).dt.strftime('%Y-%m-%d')

df = df.replace(np.nan, '', regex=True)

# df[['Invoice Amount']] = df[['Invoice Amount']].astype(float)

# %%
# df = df.replace(r"^ +| +$", r"", regex=True)
df = df.replace(np.nan, '', regex=True)
df[['LC Amount', '$AR Amount', '$CC Amount','$As Reported Rate', 'BP FX RATE']] = df[['LC Amount', '$AR Amount', '$CC Amount','$As Reported Rate', 'BP FX RATE']].replace('[^0-9]', '', regex=True)
df[['LC Amount', '$AR Amount', '$CC Amount','$As Reported Rate', 'BP FX RATE']] = df[['LC Amount', '$AR Amount', '$CC Amount','$As Reported Rate', 'BP FX RATE']].replace('', 0.0, regex=True)
df[['LC Amount', '$AR Amount', '$CC Amount','$As Reported Rate', 'BP FX RATE']] = df[['LC Amount', '$AR Amount', '$CC Amount','$As Reported Rate', 'BP FX RATE']].astype(float)
df[['Actual Document Amount', 'Actual Company Amount','Total Quantity', 'Actual Group Amount', 'Company Amount','Group Amount']]= df[['Actual Document Amount', 'Actual Company Amount','Total Quantity', 'Actual Group Amount', 'Company Amount','Group Amount']].replace('', 0.0, regex=True)
df[['Actual Document Amount', 'Actual Company Amount','Total Quantity', 'Actual Group Amount', 'Company Amount','Group Amount']]= df[['Actual Document Amount', 'Actual Company Amount','Total Quantity', 'Actual Group Amount', 'Company Amount','Group Amount']].astype(float)
# df['Posting Date'] = pd.to_datetime(df["Posting Date"]).dt.strftime('%m/%d/%Y')
df['Posting Date'] = df["Posting Date"].astype('string').replace('\.0', '', regex=True)

# %%
df['Posting Date'] = df["Posting Date"].astype('string').replace('\.0', '', regex=True)

# %%
# df['Posting Date'].unique()

# %%
df
# Out:
#                                         CONCAT Controlling Area   Document  \
# 0        2022110239705413577580864992211700041             ASHI  135775808
# 1       20221102397054135775808127992843700040             ASHI  135775808
# 2       20221102397054135775808350359031700048             ASHI  135775808
# 3       20221102397054135775808512302854700041             ASHI  135775808
# 4       20221102397055135775809100302768700016             ASHI  135775809
# ...                                        ...              ...        ...
# 333530            20227 3221096681992502728518             ASHI  322109668
# 333531    202212487265832227936770305561728565             ASHI  322279367
# 333532     20221248864623223024492302664702001             ASHI  322302449
# 333533     20221248864653223024522302667702001             ASHI  322302452
# 333534     20221248877983223037742302667702001             ASHI  322303774
#
# ...

# %%
df.columns
# Out:
# Index(['Concat', 'Reporting_Line', 'ProfitCenterSBUDesc', 'COGS Adder Review',
#        'Fiscal Period'],
#       dtype='object')

# %%
# df[[ 'Cost Element', 'Cost Center', 'LC Amount', '$AR Amount',
#        '$CC Amount', '$AR Rate', 'Company Currency', 'Company',
#        'Functional Area', 'Fiscal Year', 'Fiscal Period', 'Calendar Year',
#        'Calendar Month']] = df[[ 'Cost Element', 'Cost Center', 'LC Amount', '$AR Amount',
#        '$CC Amount', '$AR Rate', 'Company Currency', 'Company',
#        'Functional Area', 'Fiscal Year', 'Fiscal Period', 'Calendar Year',
#        'Calendar Month']].astype('string')

# %%
# df = df.apply(lambda x: x.str.replace(',',''))

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30612/1243995719.py in <module>
# ----> 1 df[[ 'Invoice Date', 'Month Work Performed ']] = pd.to_datetime(df[[ 'Invoice Date', 'Month Work Performed ']]).dt.strftime('%Y-%m-%d')
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# --> 890         result = _assemble_from_unit_mappings(arg, errors, tz)
#     891     elif isinstance(arg, Index):
#     892         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ...

# %%
df[['Company Code', 'Customer Group', 'Input Sales Group', 'FiscalPeriod',
       'Datasource']] = df[['Company Code', 'Customer Group', 'Input Sales Group', 'FiscalPeriod',
       'Datasource']].astype('string').replace('\.0', '', regex=True)

# %%
# df[['Cost Element','F18','Company']] = df[['Cost Element','F18','Company']].replace(np.nan,'', regex=True)
# df = df.replace(np.nan, '', regex=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282 entries, 0 to 2281
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Concat               2282 non-null   string
#  1   Reporting_Line       2282 non-null   string
#  2   ProfitCenterSBUDesc  2282 non-null   string
#  3   COGS Adder Review    2282 non-null   float64
#  4   Fiscal Period        2282 non-null   string
# dtypes: float64(1), string(4)
# memory usage: 89.3 KB

# %%
df.columns
# Out:
# Index(['Firms', 'Invoice #', 'Invoice Date', 'Month Work Performed ', 'Matter',
#        'Classification', 'Projects', 'Regions', 'Countries', 'Invoice Amount',
#        'Column1', 'Notes', 'Owner', 'Sent to SAP'],
#       dtype='object')

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import urllib
import sqlalchemy as sa
import pyodbc
import time
from fast_to_sql import fast_to_sql as fts

start = time.time()
#Connecting to SQL 
conn = pyodbc.connect("""
DRIVER={SQL Server Native Client 11.0};
SERVER= NAAZUREEDWS01;
UID= svc_tableau_dev;
PWD= EwSol@321$;
DATABASE=TableauDB;
trusted_connection=Yes""")

# fts.fast_to_sql(df,'rpt.ManualCOGS_Temp',conn, if_exists="append", custom={'Concat':'nvarchar(225)','Reporting_Line':'nvarchar(225)',"ProfitCenterSBUDesc":'nvarchar(225)'
#                                                                                   ,"Fiscal Period":'nvarchar(225)',"COGS Adder Review":'float(53)'}, temp=False)


fts.fast_to_sql(df,'rpt.ManualVendorUpdate_LATEST1',conn, if_exists="append",  temp=False)

conn.commit()
conn.close()
end = time.time()
delta = end - start
print("took %.2f seconds to process" % delta)
print("Update Completed")

# %%
# import pandas as pd
# import sqlalchemy as sa
# import time

# start = time.time()

# connection_string = ("""
# DRIVER={SQL Server Native Client 11.0};
# SERVER= NAAZUREEDWS01;
# UID= svc_tableau_dev;
# PWD= EwSol@321$;
# DATABASE=TableauDB;
# trusted_connection=Yes""")

# connection_url = sa.engine.URL.create(
#     "mssql+pyodbc", 
#     query=dict(odbc_connect=connection_string)
# )
# engine = sa.create_engine(connection_url, fast_executemany=False)

# df.to_sql('ManualWarehouseBP1',engine,schema= 'rpt',if_exists= "replace", index=False)


# end = time.time()
# delta = end - start
# print("took %.2f seconds to process" % delta)
# print("Update Completed")
# Out:
# took 21.54 seconds to process
# Update Completed

# %%
PricingHUBDB.[rpt].[ManualVendorUpdate]

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import urllib
import sqlalchemy as sa
import pyodbc
import time
from fast_to_sql import fast_to_sql as fts

start = time.time()
#Connecting to SQL 
conn = pyodbc.connect("""
DRIVER={SQL Server Native Client 11.0};
SERVER= NAAZUREEDWS01;
UID= svc_tableau_dev;
PWD= EwSol@321$;
DATABASE=PricingHUBDB;
trusted_connection=Yes""")

# fts.fast_to_sql(df,'rpt.ManualWarehouseBP1',conn, if_exists="replace", custom={'Cost Element':'nvarchar(225)','Cost Center':'nvarchar(225)','LC Amount':'nvarchar(225)','$AR Amount':'nvarchar(225)','$CC Amount':'nvarchar(225)',
#                                                                                   '$AR Rate':'nvarchar(225)','Company Currency':'nvarchar(225)','Company':'nvarchar(225)','Functional Area':'nvarchar(225)',
#                                                                                          'Fiscal Year':'nvarchar(225)','Fiscal Period':'nvarchar(225)','Calendar Year':'nvarchar(225)','Calendar Month':'nvarchar(225)'}, temp=False)


# fts.fast_to_sql(df,'rpt.ManualVendorUpdate1',conn, if_exists="append",  temp=False)

conn.commit()
conn.close()
end = time.time()
delta = end - start
print("took %.2f seconds to process" % delta)
print("Update Completed")
# Out:
# took 3.63 seconds to process
# Update Completed

# %%
75045531660.3100-308221902.7600
# Out:
# 74737309757.55

# %%
77438931608.6200-291955925.4400
# Out:
# 77146975683.18
